# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
print("Done")
# Out:
# Done

# %%
x=dataset[['TV','Radio','Newspaper']]
y=dataset['Sales']
print(x,y)





xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,shuffle=True)
print(xtrain,ytrain)




from sklearn.linear_model import LinearRegression
mlr=LinearRegression()
mlr.fit(xtrain,ytrain)
print(mlr)
print(mlr.intercept_)
print(list(zip(x,mlr.coef_)))

ypred = mlr.predict(xtest)

sns.regplot(x=ytest,y=ypred,ci=None)
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns] 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64
#         TV  Radio  Newspaper
# 18    69.2   20.5       18.3
# 169  284.3   10.6        6.4
# 38    43.1   26.7       35.1
# 14   204.1   32.9       46.0
# 6     57.5   32.8       23.5
# ..     ...    ...        ...
# 39   228.0   37.7       32.0
# 95   163.3   31.6       52.9
# 86    76.3   27.5       16.0
# 181  218.5    5.4       27.4
# 35   290.7    4.1        8.5
#
# [140 rows x 3 columns] 18     11.3
# 169    15.0
# 38     10.1
# 14     19.0
# 6      11.8
#        ...
# 39     21.5
# 95     16.9
# 86     12.0
# 181    12.2
# 35     12.8
# Name: Sales, Length: 140, dtype: float64
# LinearRegression()
# 2.7938923596107905
# [('TV', 0.045083714767599904), ('Radio', 0.19701161658714672), ('Newspaper', -0.00012976327525202058)]
# <AxesSubplot:xlabel='Sales'>
